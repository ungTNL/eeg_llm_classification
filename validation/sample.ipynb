# %%
import pandas as pd

df = pd.read_excel('../data/EEG_PHI_Included_max_chop_time_filter.xlsx')

df2 = df.sample(1000, random_state=42)

df2 = df2.drop(columns=['Unnamed: 0'])
df2.columns
# Out:
# Index(['note_id', 'note_text'], dtype='object')

# %%
df2.to_excel('../data/EEG_PHI_Included_max_chop_time_filter_sample.xlsx', index=False)

# %%
df2.shape
# Out:
# (1000, 2)
